# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# %%
from tqdm import tqdm # done

# %%
from sklearn import model_selection   # make use of 'SciKit Learn' library
from sklearn import linear_model
from sklearn import preprocessing
from sklearn import feature_selection
from sklearn import metrics

# %%
pip install optbinning
# Out:
# Collecting optbinning
#   Downloading optbinning-0.18.0-py3-none-any.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.6/211.6 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from optbinning) (3.7.1)
# Requirement already satisfied: numpy>=1.16.1 in /usr/local/lib/python3.10/dist-packages (from optbinning) (1.23.5)
# Collecting ortools>=9.4 (from optbinning)
#   Downloading ortools-9.7.2996-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from optbinning) (1.5.3)
# Collecting ropwr>=1.0.0 (from optbinning)
#   Downloading ropwr-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from optbinning) (1.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from optbinning) (1.11.3)
# Requirement already satisfied: absl-py>=0.13 in /usr/local/lib/python3.10/dist-packages (from ortools>=9.4->optbinning) (1.4.0)
# Collecting protobuf>=4.23.3 (from ortools>=9.4->optbinning)
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 34.8 MB/s eta 0:00:00
# Requirement already satisfied: cvxpy>=1.1.14 in /usr/local/lib/python3.10/dist-packages (from ropwr>=1.0.0->optbinning) (1.3.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->optbinning) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->optbinning) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->optbinning) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->optbinning) (2023.3.post1)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning) (0.6.2.post8)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning) (2.0.12)
# Requirement already satisfied: scs>=1.1.6 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning) (3.2.3)
# Requirement already satisfied: setuptools>65.5.1 in /usr/local/lib/python3.10/dist-packages (from cvxpy>=1.1.14->ropwr>=1.0.0->optbinning) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->optbinning) (1.16.0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.10/dist-packages (from osqp>=0.4.1->cvxpy>=1.1.14->ropwr>=1.0.0->optbinning) (0.1.7.post0)
# Installing collected packages: protobuf, ortools, ropwr, optbinning
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.24.4 which is incompatible.
# Successfully installed optbinning-0.18.0 ortools-9.7.2996 protobuf-4.24.4 ropwr-1.0.0

# %%
import optbinning
# Out:
# (CVXPY) Oct 26 12:22:17 PM: Encountered unexpected exception importing solver GLOP:
# RuntimeError('Unrecognized new version of ortools (9.7.2996). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')
# (CVXPY) Oct 26 12:22:17 PM: Encountered unexpected exception importing solver PDLP:
# RuntimeError('Unrecognized new version of ortools (9.7.2996). Expected < 9.5.0.Please open a feature request on cvxpy to enable support for this version.')

# %%
# some text no written come back later

# %%
# %%time
test = pd.read_feather("/content/drive/MyDrive/Project : Credit Default/Data Sets /test.feather")
# Out:
# CPU times: user 17.4 s, sys: 4.42 s, total: 21.9 s
# Wall time: 1min 27s

# %%
# %%time
train = pd.read_feather("/content/drive/MyDrive/Project : Credit Default/Data Sets /train.feather")
labels = pd.read_csv("/content/drive/MyDrive/Project : Credit Default/Data Sets /train_labels.csv")
# Out:
# CPU times: user 8.76 s, sys: 2.65 s, total: 11.4 s
# Wall time: 45.6 s

# %%
train.shape, test.shape , labels.shape   # check the dimension of data sets
# Out:
# ((5531451, 190), (11363762, 190), (458913, 2))

# %%
train.head()
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938477
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936523
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954102
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960449
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947266
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001734  0.008728  1.006836  0.009224  0.124023  0.008774  0.004707  ...
# 1  0.005775  0.004925  1.000977  0.006153  0.126709  0.000798  0.002714  ...
# 2  0.091492  0.021652  1.009766  0.006817  0.123962  0.007599  0.009422  ...
# 3  0.002455  0.013687  1.002930  0.001372  0.117188  0.000685  0.005531  ...
# 4  0.002483  0.015190  1.000977  0.007607  0.117310  0.004654  0.009308  ...
#
#    D_136  D_137  D_138     D_139     D_140     D_141  D_142     D_143  \
# 0    NaN    NaN    NaN  0.002426  0.003706  0.003819    NaN  0.000569
# 1    NaN    NaN    NaN  0.003956  0.003166  0.005032    NaN  0.009575
# 2    NaN    NaN    NaN  0.003269  0.007328  0.000427    NaN  0.003429
# 3    NaN    NaN    NaN  0.006119  0.004517  0.003201    NaN  0.008423
# 4    NaN    NaN    NaN  0.003672  0.004944  0.008888    NaN  0.001670
#
#       D_144     D_145
# 0  0.000610  0.002674
# 1  0.005493  0.009216
# 2  0.006985  0.002604
# 3  0.006527  0.009598
# 4  0.008125  0.009827
#
# [5 rows x 190 columns]

# %%
labels.describe() # taget column of 'labels' define the 'defaulter' and 'non defaulter' by 1 and 0 respectively
# Out:
#               target
# count  458913.000000
# mean        0.258934
# std         0.438050
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
labels.head()
# Out:
#                                          customer_ID  target
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...       0
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...       0
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...       0
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...       0
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...       0

# %%
test.head()
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-02-19  0.631348
# 1  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-03-25  0.586914
# 2  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-04-25  0.608887
# 3  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-05-20  0.614746
# 4  00000469ba478561f23a92a868bd366de6f6527a684c9a...  2019-06-15  0.591797
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001912  0.010727  0.814453  0.007545  0.168701  0.009972  0.002348  ...
# 1  0.005276  0.011024  0.811035  0.001817  0.241333  0.000166  0.009132  ...
# 2  0.003326  0.016388  1.004883  0.000114  0.267090  0.004196  0.004192  ...
# 3  0.009064  0.021667  0.816406  0.009720  0.188965  0.004124  0.015327  ...
# 4  0.238770  0.015930  0.810547  0.002026  0.180054  0.000731  0.011284  ...
#
#    D_136  D_137  D_138     D_139     D_140     D_141  D_142     D_143  \
# 0    NaN    NaN    NaN       NaN  0.004669       NaN    NaN       NaN
# 1    NaN    NaN    NaN  0.000142  0.004940  0.009018    NaN  0.003695
# 2    NaN    NaN    NaN  0.000074  0.002113  0.004658    NaN  0.003155
# 3    NaN    NaN    NaN  0.004742  0.006393  0.002890    NaN  0.006042
# 4    NaN    NaN    NaN  0.008133  0.004330  0.008385    NaN  0.001008
#
#       D_144     D_145
# 0  0.008278       NaN
# 1  0.003754  0.001460
# 2  0.002155  0.006481
# 3  0.005207  0.007858
# 4  0.007420  0.009468
#
# [5 rows x 190 columns]

# %%
figure, axis = plt.subplots(figsize = (11,6))   # subplot is used to
sns.countplot(x = labels.target)     # learn how this worked ? how to change colour too
plt.show()

# %%
# Now, lets vizualize our training data to do more Exploratory Data Analysis

# %%
figure, axis = figure, axis = plt.subplots(figsize = (11,6))
set_first = set(train.customer_ID.unique())    # convert into set to make venn diagram
set_second = set(test.customer_ID.unique())
venn2([set_first, set_second],("Training_values","Testing_Values"))
plt.show()   # from here we find that there are no 'common' customer_ID in test and train data

# %%
# time part skipped later on

# %%
# Number of User Profiles vs Timeline

# %%
figure, axis = figure, axis = plt.subplots(figsize = (20,5))  # width = 20, length  = 5
train.groupby('S_2')['customer_ID'].count().plot()
plt.title("Train Profiles vs Timeline")

figure, axis = figure, axis = plt.subplots(figsize = (20,5))
test.groupby('S_2')['customer_ID'].count().plot()
plt.title("Test Profiles vs Timeline")
# Out:
# Text(0.5, 1.0, 'Test Profiles vs Timeline')

# %%
# It is evident form the plots that train data is much more 'consistent' than the test data.

# %%
# Now we will calculate 'Weight of Evidence' and 'Information Value'

# %%
train.head()
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09  0.938477
# 1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07  0.936523
# 2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28  0.954102
# 3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13  0.960449
# 4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16  0.947266
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.001734  0.008728  1.006836  0.009224  0.124023  0.008774  0.004707  ...
# 1  0.005775  0.004925  1.000977  0.006153  0.126709  0.000798  0.002714  ...
# 2  0.091492  0.021652  1.009766  0.006817  0.123962  0.007599  0.009422  ...
# 3  0.002455  0.013687  1.002930  0.001372  0.117188  0.000685  0.005531  ...
# 4  0.002483  0.015190  1.000977  0.007607  0.117310  0.004654  0.009308  ...
#
#    D_136  D_137  D_138     D_139     D_140     D_141  D_142     D_143  \
# 0    NaN    NaN    NaN  0.002426  0.003706  0.003819    NaN  0.000569
# 1    NaN    NaN    NaN  0.003956  0.003166  0.005032    NaN  0.009575
# 2    NaN    NaN    NaN  0.003269  0.007328  0.000427    NaN  0.003429
# 3    NaN    NaN    NaN  0.006119  0.004517  0.003201    NaN  0.008423
# 4    NaN    NaN    NaN  0.003672  0.004944  0.008888    NaN  0.001670
#
#       D_144     D_145
# 0  0.000610  0.002674
# 1  0.005493  0.009216
# 2  0.006985  0.002604
# 3  0.006527  0.009598
# 4  0.008125  0.009827
#
# [5 rows x 190 columns]

# %%
# So basically we are taking last transactions of each customer_ID
train = train.groupby("customer_ID").tail(1).reset_index(drop = True)
test = test.groupby("customer_ID").tail(1).reset_index(drop = True)

# %%
train.head()
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-03-13  0.934570
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...  2018-03-25  0.880371
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...  2018-03-12  0.880859
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...  2018-03-29  0.621582
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...  2018-03-30  0.872070
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.009117  0.009384  1.007812  0.006104  0.135010  0.001604  0.007175  ...
# 1  0.178101  0.034698  1.003906  0.006912  0.165527  0.005550  0.005070  ...
# 2  0.009705  0.004284  0.812500  0.006451       NaN  0.003796  0.007195  ...
# 3  0.001082  0.012566  1.005859  0.007828  0.287842  0.004532  0.009941  ...
# 4  0.005573  0.007679  0.815918  0.001247       NaN  0.000231  0.005527  ...
#
#    D_136  D_137  D_138     D_139     D_140     D_141  D_142     D_143  \
# 0    NaN    NaN    NaN  0.007187  0.004234  0.005085    NaN  0.005810
# 1    NaN    NaN    NaN  0.002981  0.007481  0.007874    NaN  0.003284
# 2    NaN    NaN    NaN  0.007381  0.006622  0.000965    NaN  0.002201
# 3    NaN    NaN    NaN  0.002705  0.006184  0.001899    NaN  0.008186
# 4    NaN    NaN    NaN  0.002974  0.004162  0.005764    NaN  0.008156
#
#       D_144     D_145
# 0  0.002970  0.008530
# 1  0.003170  0.008514
# 2  0.000834  0.003445
# 3  0.005558  0.002983
# 4  0.006943  0.000905
#
# [5 rows x 190 columns]

# %%
train.isna().sum()
# Out:
# customer_ID         0
# S_2                 0
# P_2              2969
# D_39                0
# B_1                 0
#                 ...
# D_141            2830
# D_142          378598
# D_143            2830
# D_144               0
# D_145            2830
# Length: 190, dtype: int64

# %%
labels.describe()
# Out:
#               target
# count  458913.000000
# mean        0.258934
# std         0.438050
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
labels.head()
labels.isna().sum()
# Out:
# customer_ID    0
# target         0
# dtype: int64

# %%
# merging with the targets values
train = train.merge(labels, on = 'customer_ID', how = 'left')

# %%
train.head() # check if there are a total of 380 rows or not
# Out:
#                                          customer_ID         S_2       P_2  \
# 0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2018-03-13  0.934570
# 1  00000fd6641609c6ece5454664794f0340ad84dddce9a2...  2018-03-25  0.880371
# 2  00001b22f846c82c51f6e3958ccd81970162bae8b007e8...  2018-03-12  0.880859
# 3  000041bdba6ecadd89a52d11886e8eaaec9325906c9723...  2018-03-29  0.621582
# 4  00007889e4fcd2614b6cbe7f8f3d2e5c728eca32d9eb8a...  2018-03-30  0.872070
#
#        D_39       B_1       B_2       R_1       S_3      D_41       B_3  ...  \
# 0  0.009117  0.009384  1.007812  0.006104  0.135010  0.001604  0.007175  ...
# 1  0.178101  0.034698  1.003906  0.006912  0.165527  0.005550  0.005070  ...
# 2  0.009705  0.004284  0.812500  0.006451       NaN  0.003796  0.007195  ...
# 3  0.001082  0.012566  1.005859  0.007828  0.287842  0.004532  0.009941  ...
# 4  0.005573  0.007679  0.815918  0.001247       NaN  0.000231  0.005527  ...
#
#    D_137  D_138     D_139     D_140     D_141  D_142     D_143     D_144  \
# 0    NaN    NaN  0.007187  0.004234  0.005085    NaN  0.005810  0.002970
# 1    NaN    NaN  0.002981  0.007481  0.007874    NaN  0.003284  0.003170
# 2    NaN    NaN  0.007381  0.006622  0.000965    NaN  0.002201  0.000834
# 3    NaN    NaN  0.002705  0.006184  0.001899    NaN  0.008186  0.005558
# 4    NaN    NaN  0.002974  0.004162  0.005764    NaN  0.008156  0.006943
#
#       D_145  target
# 0  0.008530       0
# 1  0.008514       0
# 2  0.003445       0
# 3  0.002983       0
# 4  0.000905       0
#
# [5 rows x 191 columns]

# %%
drop_cols = ['customer_ID','S_2','target'] # we will drop themm as they are
# not useful for the model and unnecessarily make slow
train_cols = [_ for _ in train.columns if _ not in drop_cols]

# %%
len(train_cols)
# Out:
# 188

# %%
categorical = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']

# IV score claculation for categorical and numerical type of data

iv_dict = {}
for _ in tqdm(train_cols): # what is this tqdm doing here?
  if _ in categorical :
    ob = optbinning.OptimalBinning(dtype = 'categorical')
    ob.fit(train[_],train['target'])
  else:
    ob = ob = optbinning.OptimalBinning(dtype = 'numerical')
    ob.fit(train[_],train['target'])
  binning_table = ob.binning_table
  binning_table.build()  # build does ?
  iv_dict[_] = binning_table.iv

iv_df = pd.Series(iv_dict)
iv_df.sort_values(ascending  = False, inplace = True )
# what inplace is doing there ?
# Series ?
# Out:
# 100%|██████████| 188/188 [01:17<00:00,  2.44it/s]

# %%
iv_df.head(75) # top 75 features
# Out:
# P_2     3.732496
# D_48    2.406650
# B_18    2.212995
# B_7     2.106675
# D_75    2.070369
#           ...
# D_72    0.392019
# R_3     0.389353
# R_26    0.379131
# D_56    0.372086
# S_27    0.361552
# Length: 75, dtype: float64

# %%
# Comparison: iv scores and features (graph)
figure, axis = plt.subplots(figsize = (15,5))
iv_df.reset_index(drop = True).plot()
# add x and y labels
plt.show()

# %%
# Okay, so we will try to analyse WoE values and its plot for any onw feature

# %%
ob = optbinning.OptimalBinning(dtype = 'numerical')
ob.fit(train['P_2'],train['target']) # we will chechk for 'P_2' column name
# 'P_2' has highest Information Value(IV)
binning_table = ob.binning_table
display(binning_table.build())

# Note: 'P_2' is a continuous feature splitted into 15 bins
# Out:
#                  Bin   Count  Count (%)  Non-event   Event  Event rate  \
# 0       (-inf, 0.18)   29733   0.064790       2631   27102    0.911512
# 1       [0.18, 0.32)   34240   0.074611       8586   25654    0.749241
# 2       [0.32, 0.43)   40102   0.087385      15556   24546    0.612089
# 3       [0.43, 0.52)   41474   0.090374      22460   19014    0.458456
# 4       [0.52, 0.58)   28361   0.061800      19500    8861    0.312436
# 5       [0.58, 0.64)   32780   0.071430      26363    6417    0.195760
# 6       [0.64, 0.69)   22969   0.050051      20396    2573    0.112021
# 7       [0.69, 0.73)   23797   0.051855      22171    1626    0.068328
# 8       [0.73, 0.77)   24883   0.054222      23932     951    0.038219
# 9       [0.77, 0.82)   33368   0.072711      32634     734    0.021997
# 10      [0.82, 0.85)   23436   0.051069      23187     249    0.010625
# 11      [0.85, 0.88)   26085   0.056841      25872     213    0.008166
# 12      [0.88, 0.93)   40208   0.087616      39988     220    0.005472
# 13      [0.93, 0.97)   29920   0.065198      29808     112    0.003743
# 14       [0.97, inf)   24588   0.053579      24527      61    0.002481
# 15           Special       0   0.000000          0       0    0.000000
# 16           Missing    2969   0.006470       2474     495    0.166723
# Totals                458913   1.000000     340085  118828    0.258934
#
#              WoE        IV        JS
# 0      -3.383762  0.745582  0.064705
# 1      -2.146085  0.409141  0.043147
# 2      -1.507621  0.242465  0.027729
# 3      -0.884958  0.083160  0.010069
# 4      -0.262764  0.004528  0.000564
# 5       0.361492  0.008501  0.001057
# 6       1.018748  0.039039  0.004679
# 7       1.561144  0.080413  0.009141
# 8       2.173939  0.135583  0.014242
# 9       2.743082  0.246278  0.023740
# 10      3.482376  0.230131  0.019643
# 11      3.748106  0.278419  0.022721
# 12      4.151189  0.480421  0.036617
# 13      4.532515  0.392997  0.028094
# 14      4.945137  0.354106  0.023646
# 15           0.0  0.000000  0.000000
# 16      0.557515  0.001733  0.000214
# Totals            3.732496  0.330007

# %%
display(binning_table.plot(metric = "woe"))  # how is this syntax working?
# try changing the colours
# write graph insights also
# Out:
# None

# %%
# later on : WoE plot for top 10 features

# %%
categorical
# Out:
# ['B_30',
#  'B_38',
#  'D_114',
#  'D_116',
#  'D_117',
#  'D_120',
#  'D_126',
#  'D_63',
#  'D_64',
#  'D_66',
#  'D_68']

# %%
len(train_cols)
# Out:
# 188

# %%
# Now, we will select the features for IV values > 0.5

s_f = iv_df[iv_df > 0.5].index.values  # s_f = selected features
categorical = [_ for _ in categorical if _ in s_f]
train_cols = [_ for _ in train.columns if _ in s_f]

# %%
len(s_f) , categorical , len(train_cols) # 63 numerical and 2 categorical columns
# Out:
# (63, ['B_30', 'B_38'], 63)

# %%
# Correlation Heatmap

# %%
top_columns = [_ for _ in s_f[:15] if _ in train_cols]
corr_df = train[top_columns].corr()
plt.figure(figsize = (15,9))
sns.heatmap(corr_df,annot = True, cmap = sns.color_palette("ch:start=.2,rot=-.3",2)) # why annot and cmap is used ?
plt.show()
# how to print using seaborn and plt ?

# %%
len(top_columns) , corr_df  # how it is printing to corr table
# Out:
# (15,
#             P_2      D_48      B_18       B_7      D_75      D_61      B_23  \
#  P_2   1.000000 -0.787644  0.632005 -0.554713 -0.576487 -0.702596 -0.542867
#  D_48 -0.787644  1.000000 -0.713715  0.653358  0.593070  0.842864  0.649319
#  B_18  0.632005 -0.713715  1.000000 -0.677745 -0.710749 -0.718609 -0.678302
#  B_7  -0.554713  0.653358 -0.677745  1.000000  0.594365  0.620642  0.994963
#  D_75 -0.576487  0.593070 -0.710749  0.594365  1.000000  0.599326  0.614836
#  D_61 -0.702596  0.842864 -0.718609  0.620642  0.599326  1.000000  0.618801
#  B_23 -0.542867  0.649319 -0.678302  0.994963  0.614836  0.618801  1.000000
#  B_10  0.028175 -0.058479  0.051395 -0.037248 -0.035612 -0.040702 -0.036088
#  B_9  -0.590443  0.575720 -0.599462  0.512597  0.479067  0.504978  0.505602
#  D_44 -0.598986  0.666615 -0.554368  0.533120  0.787766  0.590814  0.554856
#  B_2   0.598488 -0.617269  0.860164 -0.615821 -0.583619 -0.562873 -0.608465
#  B_6   0.096549 -0.131789  0.151390 -0.115780 -0.110819 -0.138213 -0.113028
#  B_3  -0.496107  0.549517 -0.667215  0.645042  0.522646  0.498370  0.652157
#  B_1  -0.399714  0.443577 -0.575327  0.650640  0.382041  0.402166  0.653540
#  B_37 -0.398899  0.442842 -0.574525  0.649001  0.381028  0.400584  0.651761
#
#            B_10       B_9      D_44       B_2       B_6       B_3       B_1  \
#  P_2   0.028175 -0.590443 -0.598986  0.598488  0.096549 -0.496107 -0.399714
#  D_48 -0.058479  0.575720  0.666615 -0.617269 -0.131789  0.549517  0.443577
#  B_18  0.051395 -0.599462 -0.554368  0.860164  0.151390 -0.667215 -0.575327
#  B_7  -0.037248  0.512597  0.533120 -0.615821 -0.115780  0.645042  0.650640
#  D_75 -0.035612  0.479067  0.787766 -0.583619 -0.110819  0.522646  0.382041
#  D_61 -0.040702  0.504978  0.590814 -0.562873 -0.138213  0.498370  0.402166
#  B_23 -0.036088  0.505602  0.554856 -0.608465 -0.113028  0.652157  0.653540
#  B_10  1.000000 -0.025221 -0.025901  0.036932  0.047572 -0.028870 -0.025769
#  B_9  -0.025221  1.000000  0.478133 -0.637669 -0.085297  0.567175  0.550328
#  D_44 -0.025901  0.478133  1.000000 -0.483311 -0.083169  0.479925  0.347292
#  B_2   0.036932 -0.637669 -0.483311  1.000000  0.115583 -0.720642 -0.627207
#  B_6   0.047572 -0.085297 -0.083169  0.115583  1.000000 -0.096205 -0.082761
#  B_3  -0.028870  0.567175  0.479925 -0.720642 -0.096205  1.000000  0.735629
#  B_1  -0.025769  0.550328  0.347292 -0.627207 -0.082761  0.735629  1.000000
#  B_37 -0.025659  0.546604  0.346928 -0.630070 -0.082349  0.738160  0.992982
#
#            B_37
#  P_2  -0.398899
#  D_48  0.442842
#  B_18 -0.574525
#  B_7   0.649001
#  D_75  0.381028
#  D_61  0.400584
#  B_23  0.651761
#  B_10 -0.025659
#  B_9   0.546604
#  D_44  0.346928
#  B_2  -0.630070
#  B_6  -0.082349
#  B_3   0.738160
#  B_1   0.992982
#  B_37  1.000000  )

# %%
def drop_feature_selection(r , c , corr , r_id , c_id):
  if r_id >= c_id:
    return c
  else :
    return r

# %%
cor_mat = train[train_cols].corr().abs()
upper_tri = cor_mat.where(np.triu(np.ones(cor_mat.shape),k=1).astype(np.bool_))
corr_df = upper_tri.stack().reset_index()
corr_df.columns = ['row', 'col', 'corr']
corr_df = corr_df.drop_duplicates()
corr_df = corr_df.sort_values('corr', ascending=False)
corr_df = corr_df.query("corr >= 0.8") # query similar to SQL
corr_df['row_iv'] = corr_df['row'].map(iv_dict)
corr_df['col_iv'] = corr_df['col'].map(iv_dict)

corr_df['drop_feature'] = corr_df.apply(lambda x: drop_feature_selection(x['row'], x['col'], x['corr'], x['row_iv'], x['col_iv']), axis=1)

# %%
corr_df
# Out:
#        row   col      corr    row_iv    col_iv drop_feature
# 1531  D_62  D_77  0.999824  1.660473  1.176555         D_77
# 144    B_1  B_11  0.995629  1.829305  1.749460         B_11
# 898    B_7  B_23  0.994963  2.106675  2.059052         B_23
# 179    B_1  B_37  0.992982  1.829305  1.801300         B_37
# 1782  D_74  D_75  0.988533  1.554889  2.070369         D_74
# 1246  B_11  B_37  0.988209  1.749460  1.801300         B_11
# 1926  S_22  S_24  0.965077  0.795160  0.656930         S_24
# 1407  D_58  D_75  0.927898  1.512233  2.070369         D_58
# 1406  D_58  D_74  0.923637  1.512233  1.554889         D_58
# 233    B_2  B_33  0.918636  1.905190  1.638385         B_33
# 320    S_3   S_7  0.909011  0.986519  0.917515          S_7
# 1578  B_16  B_20  0.897838  1.288025  1.545623         B_16
# 789   D_48  D_55  0.884178  2.406650  1.775219         D_55
# 1644  B_18  B_33  0.863453  2.212995  1.638385         B_33
# 216    B_2  B_18  0.860164  1.905190  2.212995          B_2
# 794   D_48  D_61  0.842864  2.406650  2.070309         D_61
# 1327  D_55  D_61  0.811887  1.775219  2.070309         D_55

# %%
corr_drop_features = corr_df['drop_feature'].unique().tolist() # use of tolist() ?

# %%
corr_drop_features
# Out:
# ['D_77',
#  'B_11',
#  'B_23',
#  'B_37',
#  'D_74',
#  'S_24',
#  'D_58',
#  'B_33',
#  'S_7',
#  'B_16',
#  'D_55',
#  'B_2',
#  'D_61']

# %%
# Modelling :

# %%
train_data, cv_data = model_selection.train_test_split(train, test_size=0.3, random_state=42, shuffle=True, stratify=train['target'])
train_data.shape, cv_data.shape
# Out:
# ((321239, 191), (137674, 191))

# %%
len(train_data)+len(cv_data) # hence data has been divided into CV data and Train data
# Out:
# 458913

# %%
s_f = [_ for _ in s_f if _ not in corr_drop_features]
categorical = [_ for _ in categorical if _ in s_f]
train_cols = [_ for _ in train.columns if _ in s_f]

# %%
len(s_f) , len(categorical), len(train_cols)
# after visualizing the heatmap  the predictor count which are considered is
# reduced to 50 and 2 categorical
# Out:
# (50, 2, 50)

# %%
X_train = train_data[train_cols].copy() # copy is made otherwise the two data
# points to the same address and can erroneous results
# convention to keep X capital
y_train = train_data['target'].copy()

# %%
X_cv = cv_data[train_cols].copy()
y_cv = cv_data['target'].copy()

# %%
X_test = test[train_cols].copy()

# %%
type(X_train), type(y_train) , len(X_train),len(X_cv),len(y_cv),len(X_test)
# we will test data on nearly doubled size data
# Out:
# (pandas.core.frame.DataFrame,
#  pandas.core.series.Series,
#  321239,
#  137674,
#  137674,
#  924621)

# %%
train_cols
# Out:
# ['P_2',
#  'D_39',
#  'B_1',
#  'R_1',
#  'S_3',
#  'D_41',
#  'B_3',
#  'D_43',
#  'D_44',
#  'B_4',
#  'D_45',
#  'R_2',
#  'D_47',
#  'D_48',
#  'B_6',
#  'B_7',
#  'B_8',
#  'D_51',
#  'B_9',
#  'D_52',
#  'P_3',
#  'B_10',
#  'D_53',
#  'R_4',
#  'R_5',
#  'B_14',
#  'D_60',
#  'D_62',
#  'D_65',
#  'B_17',
#  'B_18',
#  'B_19',
#  'B_20',
#  'R_6',
#  'B_22',
#  'D_70',
#  'D_75',
#  'R_7',
#  'B_25',
#  'B_26',
#  'D_78',
#  'B_28',
#  'D_84',
#  'B_30',
#  'S_22',
#  'S_23',
#  'S_25',
#  'B_38',
#  'D_112',
#  'B_40']

# %%
binning_process = optbinning.BinningProcess(variable_names = train_cols,
                                            categorical_variables = categorical)
# what is binning process?
# variable_name take all the variables names and categorical_variables take
# the categorical variables

# %%
model = linear_model.LogisticRegression()

# %%
scorecard = optbinning.Scorecard(
    binning_process = binning_process,
    estimator = model,
    scaling_method = 'min_max',
    scaling_method_params = {'min':300,'max':850}
)

# why only 300 and 850 ?
# check all parameters by referring documentation and write down in copy.
# 'pdo_odds' :  scaling_method available

# %%
# %%time
scorecard.fit(X_train,y_train) # model training
# Out:
# CPU times: user 21.8 s, sys: 1.1 s, total: 22.9 s
# Wall time: 21 s
# Scorecard(binning_process=BinningProcess(categorical_variables=['B_30', 'B_38'],
#                                          variable_names=['P_2', 'D_39', 'B_1',
#                                                          'R_1', 'S_3', 'D_41',
#                                                          'B_3', 'D_43', 'D_44',
#                                                          'B_4', 'D_45', 'R_2',
#                                                          'D_47', 'D_48', 'B_6',
#                                                          'B_7', 'B_8', 'D_51',
#                                                          'B_9', 'D_52', 'P_3',
#                                                          'B_10', 'D_53', 'R_4',
#                                                          'R_5', 'B_14', 'D_60',
#                                                          'D_62', 'D_65', 'B_17', ...]),
#           estimator=LogisticRegression(), scaling_method='min_max',
#           scaling_method_params={'max': 850, 'min': 300})

# %%
scorecard_df = scorecard.table(style = "detailed")
# storing scorecard into dataframe

# %%
scorecard_df
# Out:
#    Variable  Bin id           Bin  Count  Count (%)  Non-event  Event  \
# 0       P_2       0  (-inf, 0.18)  20868   0.064961       1836  19032
# 1       P_2       1  [0.18, 0.32)  23497   0.073145       5829  17668
# 2       P_2       2  [0.32, 0.43)  28982   0.090219      11259  17723
# 3       P_2       3  [0.43, 0.52)  28570   0.088937      15562  13008
# 4       P_2       4  [0.52, 0.58)  20532   0.063915      14129   6403
# ..      ...     ...           ...    ...        ...        ...    ...
# 7      B_40       7  [0.40, 0.49)  16063   0.050003       6964   9099
# 8      B_40       8  [0.49, 0.62)  19311   0.060114       8053  11258
# 9      B_40       9   [0.62, inf)  19610   0.061045       7030  12580
# 10     B_40      10       Special      0   0.000000          0      0
# 11     B_40      11       Missing      0   0.000000          0      0
#
#     Event rate       WoE        IV        JS  Coefficient     Points
# 0     0.912018 -3.390044  0.749514  0.064978    -0.370648 -13.599855
# 1     0.751926 -2.160421  0.405989  0.042728    -0.370648  -4.310522
# 2     0.611517 -1.505207  0.249523  0.028544    -0.370648   0.639372
# 3     0.455303 -0.872244  0.079386  0.009620    -0.370648   5.421166
# 4     0.311855 -0.260049  0.004584  0.000571    -0.370648  10.046069
# ..         ...       ...       ...       ...          ...        ...
# 7     0.566457 -1.318922  0.105693  0.012330     0.084616  14.285332
# 8     0.582984 -1.386546  0.140758  0.016308     0.084616  14.401961
# 9     0.641509 -1.633433  0.198802  0.022410     0.084616  14.827757
# 10    0.000000  0.000000  0.000000  0.000000     0.084616  12.010639
# 11    0.000000  0.000000  0.000000  0.000000     0.084616  12.010639
#
# [540 rows x 13 columns]

# %%
scorecard_df.head(10)
# Out:
#   Variable  Bin id           Bin  Count  Count (%)  Non-event  Event  \
# 0      P_2       0  (-inf, 0.18)  20868   0.064961       1836  19032
# 1      P_2       1  [0.18, 0.32)  23497   0.073145       5829  17668
# 2      P_2       2  [0.32, 0.43)  28982   0.090219      11259  17723
# 3      P_2       3  [0.43, 0.52)  28570   0.088937      15562  13008
# 4      P_2       4  [0.52, 0.58)  20532   0.063915      14129   6403
# 5      P_2       5  [0.58, 0.64)  22246   0.069251      17923   4323
# 6      P_2       6  [0.64, 0.72)  28614   0.089074      25935   2679
# 7      P_2       7  [0.72, 0.77)  21791   0.067834      20911    880
# 8      P_2       8  [0.77, 0.82)  22292   0.069394      21798    494
# 9      P_2       9  [0.82, 0.86)  22600   0.070353      22362    238
#
#    Event rate       WoE        IV        JS  Coefficient     Points
# 0    0.912018 -3.390044  0.749514  0.064978    -0.370648 -13.599855
# 1    0.751926 -2.160421  0.405989  0.042728    -0.370648  -4.310522
# 2    0.611517 -1.505207  0.249523  0.028544    -0.370648   0.639372
# 3    0.455303 -0.872244  0.079386  0.009620    -0.370648   5.421166
# 4    0.311855 -0.260049  0.004584  0.000571    -0.370648  10.046069
# 5    0.194327  0.370624  0.008642  0.001074    -0.370648  14.810559
# 6    0.093625  1.218638  0.093514  0.011016    -0.370648  21.216987
# 7    0.040384  2.116597  0.163529  0.017317    -0.370648  28.000724
# 8    0.022160  2.735526  0.234234  0.022606    -0.370648  32.676500
# 9    0.010531  3.491336  0.317968  0.027100    -0.370648  38.386354

# %%
scorecard_df.sample(25) # lets check randomly 25 values
# Out:
#    Variable  Bin id           Bin   Count  Count (%)  Non-event  Event  \
# 1      D_70       1  [0.00, 0.01)  141585   0.440747     117204  24381
# 13     D_52      13       Missing     861   0.002680        725    136
# 1       B_4       1  [0.01, 0.01)   17764   0.055298      17162    602
# 10     D_45      10  [0.40, 0.76)   51167   0.159280      45523   5644
# 1      B_18       1  [0.07, 0.13)   23599   0.073462       9263  14336
# 4      D_52       4  [0.09, 0.11)   28042   0.087293      20084   7958
# 9      S_22       9       Special       0   0.000000          0      0
# 1       R_5       1  [0.00, 0.26)  177851   0.553641     138203  39648
# 5       P_2       5  [0.58, 0.64)   22246   0.069251      17923   4323
# 13      S_3      13       Missing   59692   0.185818      53265   6427
# 0       B_7       0  (-inf, 0.03)   91513   0.284875      89599   1914
# 3       P_3       3  [0.47, 0.53)   29367   0.091418      19900   9467
# 3       P_2       3  [0.43, 0.52)   28570   0.088937      15562  13008
# 10     S_23      10       Missing      33   0.000103         11     22
# 3      B_26       3  [0.01, 0.01)   54159   0.168594      42477  11682
# 5      B_10       5  [0.05, 0.07)   22075   0.068718      14930   7145
# 0      D_47       0  (-inf, 0.05)   16305   0.050757       7855   8450
# 5      D_84       5       Missing     861   0.002680        725    136
# 9      D_78       9       Missing   15655   0.048733      11885   3770
# 9      D_45       9  [0.35, 0.40)   16860   0.052484      14960   1900
# 17     D_47      17       Missing       0   0.000000          0      0
# 7      D_52       7  [0.16, 0.19)   22854   0.071143      19326   3528
# 6       R_1       6  [0.01, 0.13)   30695   0.095552      25536   5159
# 3      B_10       3  [0.02, 0.03)   26073   0.081164      12931  13142
# 0      B_30       0       [0, -1]  268267   0.835101     219951  48316
#
#     Event rate       WoE        IV        JS  Coefficient     Points
# 1     0.172200  0.518600  0.103316  0.012772    -0.089595  12.957676
# 13    0.157956  0.622005  0.000877  0.000108    -0.036853  12.010639
# 1     0.033889  2.298684  0.149079  0.015381    -0.428728  32.097540
# 10    0.110305  1.036113  0.127828  0.015300    -0.430839  21.109220
# 1     0.607483 -1.488257  0.198591  0.022760     0.076183  14.321583
# 4     0.283789 -0.125766  0.001422  0.000178    -0.036853  11.916171
# 9     0.000000  0.000000  0.000000  0.000000    -0.110275  12.010639
# 1     0.222928  0.197172  0.020484  0.002556     0.225828  11.103081
# 5     0.194327  0.370624  0.008642  0.001074    -0.370648  14.810559
# 13    0.107669  1.063260  0.155747  0.018600    -0.334293  12.010639
# 0     0.020915  2.794637  0.987521  0.094413    -0.111778  18.377606
# 3     0.322369 -0.308604  0.009326  0.001161    -0.145958  11.092555
# 3     0.455303 -0.872244  0.079386  0.009620    -0.370648   5.421166
# 10    0.666667 -1.744659  0.000381  0.000042    -0.115939  12.010639
# 3     0.215698  0.239402  0.009094  0.001134    -0.075227  12.377714
# 5     0.323669 -0.314552  0.007292  0.000908    -0.082265  11.483216
# 0     0.518246 -1.124528  0.077132  0.009164    -0.132979   8.962707
# 5     0.157956  0.622005  0.000877  0.000108     0.032610  12.010639
# 9     0.240818  0.096690  0.000445  0.000056     0.012909  12.010639
# 9     0.112693  1.012014  0.040480  0.004855    -0.430839  20.897599
# 17    0.000000  0.000000  0.000000  0.000000    -0.132979  12.010639
# 7     0.154371  0.649209  0.025168  0.003092    -0.036853  12.498286
# 6     0.168073  0.547835  0.024787  0.003060    -0.161653  13.815667
# 3     0.504046 -1.067697  0.110695  0.013215    -0.082265  10.220383
# 0     0.180104  0.464130  0.159231  0.019727     0.037754  11.653490

# %%
# query method takes a boolean condition and returns a data frame

# %%
scorecard_df.query("Variable == 'P_2'")
# Out:
#    Variable  Bin id           Bin  Count  Count (%)  Non-event  Event  \
# 0       P_2       0  (-inf, 0.18)  20868   0.064961       1836  19032
# 1       P_2       1  [0.18, 0.32)  23497   0.073145       5829  17668
# 2       P_2       2  [0.32, 0.43)  28982   0.090219      11259  17723
# 3       P_2       3  [0.43, 0.52)  28570   0.088937      15562  13008
# 4       P_2       4  [0.52, 0.58)  20532   0.063915      14129   6403
# 5       P_2       5  [0.58, 0.64)  22246   0.069251      17923   4323
# 6       P_2       6  [0.64, 0.72)  28614   0.089074      25935   2679
# 7       P_2       7  [0.72, 0.77)  21791   0.067834      20911    880
# 8       P_2       8  [0.77, 0.82)  22292   0.069394      21798    494
# 9       P_2       9  [0.82, 0.86)  22600   0.070353      22362    238
# 10      P_2      10  [0.86, 0.89)  16203   0.050439      16073    130
# 11      P_2      11  [0.89, 0.92)  16423   0.051124      16314    109
# 12      P_2      12  [0.92, 0.97)  29241   0.091026      29122    119
# 13      P_2      13   [0.97, inf)  17303   0.053863      17259     44
# 14      P_2      14       Special      0   0.000000          0      0
# 15      P_2      15       Missing   2077   0.006466       1747    330
#
#     Event rate       WoE        IV        JS  Coefficient     Points
# 0     0.912018 -3.390044  0.749514  0.064978    -0.370648 -13.599855
# 1     0.751926 -2.160421  0.405989  0.042728    -0.370648  -4.310522
# 2     0.611517 -1.505207  0.249523  0.028544    -0.370648   0.639372
# 3     0.455303 -0.872244  0.079386  0.009620    -0.370648   5.421166
# 4     0.311855 -0.260049  0.004584  0.000571    -0.370648  10.046069
# 5     0.194327  0.370624  0.008642  0.001074    -0.370648  14.810559
# 6     0.093625  1.218638  0.093514  0.011016    -0.370648  21.216987
# 7     0.040384  2.116597  0.163529  0.017317    -0.370648  28.000724
# 8     0.022160  2.735526  0.234234  0.022606    -0.370648  32.676500
# 9     0.010531  3.491336  0.317968  0.027100    -0.370648  38.386354
# 10    0.008023  3.765850  0.248373  0.020208    -0.370648  40.460203
# 11    0.006637  3.956919  0.265979  0.020951    -0.370648  41.903659
# 12    0.004070  4.448614  0.537839  0.038991    -0.370648  45.618225
# 13    0.002543  4.920388  0.354120  0.023743    -0.370648  49.182296
# 14    0.000000  0.000000  0.000000  0.000000    -0.370648  12.010639
# 15    0.158883  0.615051  0.002073  0.000255    -0.370648  12.010639

# %%
len(scorecard_df)
# Out:
# 540

# %%
# here we can observe feature points scores
# say if P_2 value is 0.73 then it will lie in the 7th bin and u can
# check feature  score in the last column

# %%
##### METRICS provided by the competition #####
# Understand later on

# %%
# Hidden
# --> what is this ?
#  what are weighted gini here ?


def metric(y_true, y_pred, return_components=False) -> float:
    """Amex metric for ndarrays"""
    def top_four_percent_captured(df) -> float:
        """Corresponds to the recall for a threshold of 4 %"""
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        four_pct_cutoff = int(0.04 * df['weight'].sum())
        df['weight_cumsum'] = df['weight'].cumsum()
        df_cutoff = df.loc[df['weight_cumsum'] <= four_pct_cutoff]
        return (df_cutoff['target'] == 1).sum() / (df['target'] == 1).sum()

    def weighted_gini(df) -> float:
        df['weight'] = df['target'].apply(lambda x: 20 if x==0 else 1)
        df['random'] = (df['weight'] / df['weight'].sum()).cumsum()
        total_pos = (df['target'] * df['weight']).sum()
        df['cum_pos_found'] = (df['target'] * df['weight']).cumsum()
        df['lorentz'] = df['cum_pos_found'] / total_pos
        df['gini'] = (df['lorentz'] - df['random']) * df['weight']
        return df['gini'].sum()

    def normalized_weighted_gini(df) -> float:
        """Corresponds to 2 * AUC - 1"""
        df2 = pd.DataFrame({'target': df.target, 'prediction': df.target})
        df2.sort_values('prediction', ascending=False, inplace=True)
        return weighted_gini(df) / weighted_gini(df2)

    df = pd.DataFrame({'target': y_true.ravel(), 'prediction': y_pred.ravel()})
    df.sort_values('prediction', ascending=False, inplace=True)
    g = normalized_weighted_gini(df)
    d = top_four_percent_captured(df)

    if return_components: return g, d, 0.5 * (g + d)
    return 0.5 * (g + d)

# %%
# what does scorecard.predict_prob do?  what are other things in its parameters ?
# scorecard.predict_proba(X_train) : returned several rows with 2 columns why?
train_data['pred_prob'] = scorecard.predict_proba(X_train)[:,1]
cv_data['pred_prob'] = scorecard.predict_proba(X_cv)[:,1]

# %%
train_score = metric(train_data['target'],train_data['pred_prob'])
cv_score = metric(cv_data['target'],cv_data['pred_prob'])

print("Training Score = ",train_score)
print("CV score = ", cv_score)
# Out:
# Training Score =  0.7549500586598745
# CV score =  0.7572452251998683

# %%
# what is AUC and ROC curve and how to compute and plot them?
# what are thresholds ?
# this process is repeated for CV data also
# what is this .format?
# what is this --?

# %%
fpr_t , tpr_t , thresholds = metrics.roc_curve(y_train,train_data['pred_prob'])  # it seems it returns three values
# i.e false + rate , true + rate , thresholds
opt_idx = np.argmax(tpr_t - fpr_t)
opt_threshold_t = thresholds[opt_idx]
print("Threshold Value(Train): ", opt_threshold_t)
# Out:
# Threshold Value(Train):  0.23821258211159177

# %%
fpr_cv , tpr_cv , thresholds = metrics.roc_curve(y_cv,cv_data['pred_prob'])
# it seems it returns three values
# i.e false + rate , true + rate , thresholds
opt_idx = np.argmax(tpr_cv - fpr_cv) # argmax returns the index of maximum value
# it returns 1st index even if multiple appearances
# by deafult it checks the flattened array
opt_threshold_cv = thresholds[opt_idx]
print("Threshold Value(Train): ", opt_threshold_cv)
# Out:
# Threshold Value(Train):  0.2344109155635671

# %%
# What is binning +LR ?
auc_score_t = metrics.auc(fpr_t , tpr_t)
auc_score_cv = metrics.auc(fpr_cv , tpr_cv)
plt.title("ROC curve")
plt.plot(fpr_t,tpr_t,'b',
         label = 'Binning+LR: Train AUC = {0:.4f}'.format(auc_score_t))
plt.plot(fpr_cv,tpr_cv,'r',
         label = 'Binning+LR : CV AUC = {0:.4f}'.format(auc_score_cv))

# 'b' and 'r' represent the colours
# .format() is converting the 'auc_score(s)' into string
# and then adding in the already specified string

plt.legend(loc = 'lower right') # what is loc parameter ?
plt.plot([0,1],[0,1],"--") # what does this mean ?
#plt.xlim([0,1])
#plt.ylim([0,1])
plt.xlabel('False Postive Rate ')
plt.ylabel('True Positive Rate ')
plt.show()

# %%
auc_score_t,auc_score_cv
# we can see that area under curve for both CV and Train data are almost same.
# Out:
# (0.9513135581009895, 0.9524880298469875)

# %%
train_data.columns
# Out:
# Index(['customer_ID', 'S_2', 'P_2', 'D_39', 'B_1', 'B_2', 'R_1', 'S_3', 'D_41',
#        'B_3',
#        ...
#        'D_138', 'D_139', 'D_140', 'D_141', 'D_142', 'D_143', 'D_144', 'D_145',
#        'target', 'pred_prob'],
#       dtype='object', length=192)

# %%
train_data['predict'] = (train_data['pred_prob']>opt_threshold_t).astype(int)
# astype(data_type): converts pandas object to specified data type
cv_data['predict'] = (cv_data['pred_prob']>opt_threshold_t).astype(int)

# Why opt_threshold_cv not used? what is u used it ?

# %%
train_data.head()
# Out:
#                                               customer_ID         S_2  \
# 19899   0b2b4df2624ab3bba7793b6caebd209ebc6d9de2e988bb...  2018-03-22
# 90536   32614f869c50b46ef2b19a3e8e26edb011f108aedcbda9...  2018-03-23
# 154637  560fb77a998ba14ec89631644797168df73fbaaf819403...  2018-03-23
# 284905  9ea935127f4b1223b6cb6e8f766800a146133d74d08c15...  2018-03-23
# 97891   3678d683a645be7d8342d74ef7a231b2848922690db520...  2018-03-28
#
#              P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 19899   0.861328  0.243896  0.007381  0.810059  0.003252  0.420166  0.000018
# 90536   1.000977  0.001510  0.002718  0.812500  0.008041       NaN  0.004555
# 154637  0.275146  0.002838  0.086365  0.137329  0.003109  0.340576  0.170532
# 284905  0.364746  0.117798  0.117554  0.000818  0.005150  0.257080  0.177612
# 97891   0.627930  0.269287  0.057953  1.003906  0.007607  0.097290  0.000456
#
#              B_3  ...     D_139     D_140     D_141  D_142     D_143  \
# 19899   0.013550  ...  0.000132  0.001688  0.004585    NaN  0.000289
# 90536   0.005180  ...  0.006100  0.001206  0.004078    NaN  0.005604
# 154637  0.104919  ...  0.002724  0.002096  0.009804    NaN  0.004032
# 284905  0.006168  ...  0.008820  0.009048  0.005432    NaN  0.009293
# 97891   0.009018  ...  0.000301  0.005062  0.007088    NaN  0.004883
#
#            D_144     D_145  target  pred_prob  predict
# 19899   0.004536  0.006741       0   0.011593        0
# 90536   0.004105  0.006115       0   0.002793        0
# 154637  0.005054  0.003586       1   0.422404        1
# 284905  0.009743  0.005512       1   0.752394        1
# 97891   0.001126  0.005821       0   0.017201        0
#
# [5 rows x 193 columns]

# %%
cv_data
# Out:
#                                               customer_ID         S_2  \
# 120725  43151123fd6f8a9290f65a8f56af2db5d0f504c1d8085f...  2018-03-26
# 455297  fdfa900dc36acac32ae1db2640b6b27a834eed0e374e3f...  2018-03-28
# 364070  cad1a541f10fb04af81d63db75487e10fd609346df9353...  2018-03-12
# 158101  57fb4f0508637a512682f602a302508a0fe7a033d23182...  2018-03-01
# 116805  40e7ee3e3e20eb63ffd72a10d15c61df5f7a7f648fc307...  2018-03-14
# ...                                                   ...         ...
# 73431   290ace2677812b1793625d297b79fbdb6331b12ddbbadc...  2018-03-08
# 155297  566c39bb3c83b02209473080dedf591e79127c1e13b14e...  2018-03-12
# 150293  53a181a15946940204ce6232cf18e05459a634a50e74b8...  2018-03-07
# 429069  ef38d1ff72274da521651ca5487793d1d4e7c612d280ea...  2018-03-17
# 228756  7f4c2b072d9c07d4961ac9694a26103a16295d2c08b695...  2018-03-21
#
#              P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 120725  0.926270  0.239136  0.049713  1.004883  0.000398  0.102295  0.005348
# 455297  0.534668  0.004967  0.002647  0.817383  0.006962       NaN  0.004635
# 364070  0.493164  0.708984  0.433350  0.016937  0.007015  0.292480  0.004654
# 158101  0.362305  0.470947  0.100342  0.345215  1.009766  0.056091  0.604004
# 116805  0.658203  0.362549  0.139648  0.486328  0.007393  0.451660  0.005569
# ...          ...       ...       ...       ...       ...       ...       ...
# 73431   0.497559  0.003048  0.009468  0.816895  0.009842       NaN  0.008926
# 155297  0.243164  0.002548  0.432617  0.105103  0.008232  0.156006  0.272705
# 150293  0.640625  0.564941  0.161621  0.156006  0.009384  0.124207  0.172607
# 429069 -0.012093  2.685547  0.730957  0.005791  1.503906       NaN  2.341797
# 228756  0.617188  0.154175  0.034241  0.978516  0.008553  0.508301  0.002708
#
#              B_3  ...     D_139     D_140     D_141  D_142     D_143  \
# 120725  0.003099  ...  0.003832  0.001286  0.003265    NaN  0.008537
# 455297  0.001966  ...  0.004936  0.008492  0.000273    NaN  0.008064
# 364070  1.196289  ...  0.000866  0.000270  0.006950    NaN  0.003090
# 158101  0.075256  ...  0.000896  0.003115  0.003979    NaN  0.000522
# 116805  0.091309  ...  0.005478  0.002136  0.006016    NaN  0.005192
# ...          ...  ...       ...       ...       ...    ...       ...
# 73431   0.009041  ...  0.004959  0.003481  0.000828    NaN  0.002934
# 155297  0.250977  ...  0.001993  0.000747  0.005032    NaN  0.007950
# 150293  0.171509  ...  0.006607  0.002195  0.005730    NaN  0.005798
# 429069  0.478027  ...  0.007042  0.006992  0.003048    NaN  0.008255
# 228756  0.070862  ...  0.000058  0.004658  0.009026    NaN  0.009727
#
#            D_144     D_145  target  pred_prob  predict
# 120725  0.009346  0.000345       0   0.003987        0
# 455297  0.009941  0.002853       1   0.233671        0
# 364070  0.007202  0.006798       1   0.734966        1
# 158101  0.005062  0.007244       0   0.650591        1
# 116805  0.001140  0.009018       1   0.283672        1
# ...          ...       ...     ...        ...      ...
# 73431   0.007225  0.006065       0   0.181037        0
# 155297  0.003860  0.005634       0   0.623207        1
# 150293  0.006107  0.003092       0   0.107455        0
# 429069  0.008705  0.005398       1   0.983170        1
# 228756  0.004356  0.008362       0   0.029453        0
#
# [137674 rows x 193 columns]

# %%
# Now we will make confusion Matrix
conf_matrix = metrics.confusion_matrix(train_data['target'],train_data['predict'])
figure,(ax_1,ax_2) = plt.subplots(1,2, figsize = (7,5))

sns.heatmap(conf_matrix, square = True, annot = True,
            cmap = 'Blues',fmt = 'd' ,cbar = False ,ax= ax_1)
sns.heatmap(conf_matrix/np.sum(conf_matrix), annot = True,
            cmap = 'Blues',fmt = '.2%' ,cbar = False ,ax= ax_2)
plt.show()

# Okay, so firstly u have to look the plotting parameters of these methods
# how confusion matrix is formed and what all theory is involved in it?
# what is fmt cbar annot etc.

# %%
conf_matrix = metrics.confusion_matrix(cv_data['target'],cv_data['predict'])
figure,(ax_1,ax_2) = plt.subplots(1,2, figsize = (7,5))

sns.heatmap(conf_matrix, square = True, annot = True,
            cmap = 'Blues',fmt = 'd' ,cbar = False ,ax= ax_1)
sns.heatmap(conf_matrix/np.sum(conf_matrix), annot = True,
            cmap = 'Blues',fmt = '.2%' ,cbar = False ,ax= ax_2)
plt.show()

# change the cmap thing to some other color

# %%
print(metrics.classification_report(train_data['target'], train_data['predict'], labels=[0, 1]))
# now which parameters are to be passed and why? what is labels parameters doing there ?
# what is  support in it ?
# what is macro avg adn weighted avg
# accuracy?
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.91    238059
#            1       0.69      0.91      0.78     83180
#
#     accuracy                           0.87    321239
#    macro avg       0.83      0.88      0.84    321239
# weighted avg       0.89      0.87      0.87    321239

# %%
print(metrics.classification_report(cv_data['target'],cv_data['predict'], labels=[0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91    102026
#            1       0.69      0.91      0.79     35648
#
#     accuracy                           0.87    137674
#    macro avg       0.83      0.88      0.85    137674
# weighted avg       0.89      0.87      0.88    137674

# %%
################### Scores ########################3

# %%
train_data['score'] = scorecard.score(X_train)
cv_data['score'] = scorecard.score(X_cv)
# oh wait is that the *credit score*?
# ig yes coz somewhere in the beginning I have given a range of 300 - 850

# %%
cv_data['score'].max(), cv_data['score'].min()
# Out:
# (747.5298936420206, 412.3518506327522)

# %%
# Okay, so we will try to implement other models too on this data
# And Decision tree for feature selection and try ensembles or SVM

# %%
y_test = cv_data['target']
score = cv_data['score']

mask = y_test == 0

figure, ax = plt.subplots(figsize=(13,8))
plt.hist(score[mask],label = "Non-Default",color = 'b',alpha = 0.35)
plt.hist(score[~mask],label = "Default",color = 'g',alpha = 0.35)
plt.xlabel("score")
plt.legend()
plt.show()

# %%
type(score)
# Out:
# pandas.core.series.Series

# %%
# above is the distribution of deafult vs non-default

# %%
# Distribution of scores
plt.figure(figsize=(20,10))

plt.hist(score,
         bins = 90,
         edgecolor = 'blue',
         color = "skyblue",
         linewidth = 1.1)

plt.title('Scorecard Dist.',fontweight = "bold",fontsize = 10)
plt.xlabel('Score')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Lets plot scores against Prob

# %%
plt.figure(figsize = (15,9))

plt.scatter(x = score,
            y = cv_data['pred_prob'],
            color = '#e82e60'
)
plt.title('Scores by Probability',fontweight = 'bold',fontsize = 14)
plt.xlabel('Score')
plt.ylabel('Prob')
# Out:
# Text(0, 0.5, 'Prob')

# %%
# Inference

# %%
test['Probability'] = scorecard.predict_proba(X_test)[:,1]
submit_df = test[['customer_ID','Probability']].copy()
submit_df.to_csv("Submission.csv",index = False)

# %%
submit_df.count(),submit_df.max(),submit_df.min()
# Out:
# (customer_ID    924621
#  Probability    924621
#  dtype: int64,
#  customer_ID    fffffa7cf7e453e1acc6a1426475d5cb9400859f82ff61...
#  Probability                                             0.999495
#  dtype: object,
#  customer_ID    00000469ba478561f23a92a868bd366de6f6527a684c9a...
#  Probability                                              0.00015
#  dtype: object)

# %%
temp = submit_df[submit_df['Probability']>0.5]
len(temp)
# Out:
# 220810

# %%
# Basically out of 924621 individuals 2,20,810 have the probabilty
# of defaulting in credit amount payment
